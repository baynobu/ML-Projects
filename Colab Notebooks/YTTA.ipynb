# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("/content/us-retail-sales.csv")

# %%
data['X'] = 0 #buat kolom x dengan nilai 0
X = data['X'] #buat variabel X utk menyimpan kolom x 
for i in range(0, len(data)):
  X[i] = i+1

# df = pd.DataFrame({'y1': data['Clothing'], 'y2': data['Appliances'], 'y3': data['FoodAndBeverage'], 'y4': data['Automobiles'], 'y5': data['GeneralMerchandise'], 'y6': data['BuildingMaterials'], 'x':data['X'], 'month':data['Month']})
y1 = data['Clothing']
y2 = data['Appliances']
y3 = data['FoodAndBeverage']
y4 = data['Automobiles']
y5 = data['GeneralMerchandise']
y6 = data['BuildingMaterials']
x = data['X']
month = data['Month']
data.describe()
# print(df)
# Out:
# <ipython-input-7-95cfca337a46>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[i] = i+1
#            Clothing    Appliances  FoodAndBeverage    Automobiles  \
# count    336.000000    336.000000       336.000000     336.000000
# mean   16414.744048   7569.285714     44668.348214   63576.413690
# std     5477.293118   1993.569861     10444.196145   17459.092725
# min     6938.000000   3490.000000     28126.000000   26788.000000
# 25%    12335.500000   6654.750000     35517.000000   51374.750000
# 50%    15894.500000   7414.000000     42932.500000   62704.000000
# 75%    19889.750000   8200.250000     52877.000000   74202.500000
# max    35157.000000  15458.000000     70028.000000  105884.000000
#
#        GeneralMerchandise  BuildingMaterials           X
# ...

# %%
plt.figure(figsize=[20, 16])
plt.subplot(2, 3, 1)
plt.scatter(x, y1, s = 1)
plt.grid()
plt.xlabel("Month")
plt.ylabel("Clothing")

plt.subplot(2, 3, 2)
plt.scatter(x, y2, s = 1)
plt.grid()
plt.xlabel("Month")
plt.ylabel("Appliances")

plt.subplot(2, 3, 3)
plt.scatter(x, y3, s = 1)
plt.grid()
plt.xlabel("Month")
plt.ylabel("FoodAndBeverage")

plt.subplot(2, 3, 4)
plt.scatter(x, y4, s = 1)
plt.grid()
plt.xlabel("Month")
plt.ylabel("Automobiles")

plt.subplot(2, 3, 5)
plt.scatter(x, y5, s = 1)
plt.grid()
plt.xlabel("Month")
plt.ylabel("GeneralMerchandise")

plt.subplot(2, 3, 6)
plt.scatter(x, y6, s = 1)
plt.grid()
plt.xlabel("Month")
plt.ylabel("BuildingMaterials")
plt.show()

# %%
total = 0
for i in range(0, len(y1)):
  if y1[i] > 26000:
    for j in range(i-10, i+10):
      if j >= len(y1)-11:
        break
      total += y1[j]
    avg = total/20
    y1[i] = avg

for i in range(0, 160):
   if y1[i] > 17000:
     for j in range(i-5, i+5):
       if j >= len(y1)-6:
         break
       total += y1[j]
     avg = total/10
     y1[i] = avg

plt.scatter(x, y1, s=1)
plt.grid()
plt.ylim(6938, 35157)
plt.xlim(0, 350)
plt.show()
# Out:
# <ipython-input-14-0d60e435b0ca>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y1[i] = avg
# <ipython-input-14-0d60e435b0ca>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y1[i] = avg

# %%
# split datasat train & test

# df.iloc[:(round(0.8*len(x1))), :]   #   train
# df.iloc[(round(0.8*len(x1))):, :]   #   test

# %%
def gradientdescent():
  for i in range(len(data)):
